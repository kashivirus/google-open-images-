# %%
cd /content/drive/MyDrive/Car
# Out:
# /content/drive/MyDrive/Car

# %%
# !pip install oidv6
# Out:
# ...
#      |████████████████████████████████| 66.6 MB 115 kB/s
# ...
#      |████████████████████████████████| 3.8 MB 38.9 MB/s
# ...
#      |████████████████████████████████| 8.5 MB 45.5 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 547 kB 38.6 MB/s
# ...
#      |████████████████████████████████| 138 kB 59.4 MB/s
# ...
#      |████████████████████████████████| 127 kB 48.6 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
#   Attempting uninstall: progressbar2
#     Found existing installation: progressbar2 3.38.0
# ...

# %%
# !pip install --upgrade oidv6

# %%
cd /content/drive/MyDrive/Car
# Out:
# /content/drive/MyDrive/Car

# %% [markdown]
# ![Screenshot from 2021-12-30 21-47-03.png](data:image/png;base64,...)

# %%
# !oidv6 downloader en --dataset path_to_directory --type_data all --classes Football --limit 5000
# Out:
#         Automatic download ... 716793 out of 4411031 (16%)                      Traceback (most recent call last):
#   File "/usr/local/bin/oidv6", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/oidv6/samples/run.py", line 159, in main
#     run.run()
#   File "/usr/local/lib/python3.7/dist-packages/oidv6/samples/run.py", line 153, in run
#     self.download(self._args, out)
#   File "/usr/local/lib/python3.7/dist-packages/oidv6/OIDv6.py", line 787, in download
#     if self._valid_csv(url_annotations, curr_annotations, args['yes'], out) != 200:
#   File "/usr/local/lib/python3.7/dist-packages/oidv6/OIDv6.py", line 349, in _valid_csv
#     return self._download_file(url, file, out)  # Сохранение файла с названиями классов
#   File "/usr/local/lib/python3.7/dist-packages/oidv6/OIDv6.py", line 415, in _download_file
#     for i, chunk in enumerate(r.iter_content(chunk_size = self._chunk_size)):
# ...

# %%
# !rm -r '/content/drive/MyDrive/Car/path_to_directory'

# %%
# !oidv6 downloader en --dataset path_to_directory --type_data train --classes Football --limit 4500 --yes
# Out:
# --------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# --------------------------------------------------------------------------------
# [2021-12-30 16:58:50] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# --------------------------------------------------------------------------------
# [2021-12-30 16:58:50] Checking command line arguments for validity ...
# [2021-12-30 16:58:50] Creating Directories for Metadata ...
# --------------------------------------------------------------------------------
# [2021-12-30 16:58:50] Downloading "football" ...
#     File "class-descriptions-boxable.csv" not found ...
#         Automatic download ... 24 out of 24 (100%)
#     File "oidv6-train-annotations-bbox.csv" not found ...
#         Automatic download ... 4411031 out of 4411031 (100%)
# ...

# %%
# !oidv6 downloader en  --dataset path_to_directory --type_data validation --classes Football --limit 700 --yes
# Out:
# --------------------------------------------------------------------------------
# OIDv6 - Downloading single or multiple classes from the Open Images V6 Dataset ...
# --------------------------------------------------------------------------------
# [2021-12-30 17:58:36] Start:
# 	Author: Dmitry Ryumin
# 	Email: dl_03.03.1991@mail.ru
# 	Maintainer: Dmitry Ryumin
# 	Version: 1.0.5
# --------------------------------------------------------------------------------
# [2021-12-30 17:58:36] Checking command line arguments for validity ...
# [2021-12-30 17:58:36] Creating Directories for Metadata ...
# --------------------------------------------------------------------------------
# [2021-12-30 17:58:36] Downloading "football" ...
#     File "validation-annotations-bbox.csv" not found ...
#         Automatic download ... 49034 out of 49034 (100%)
#     Extracting data from "validation-annotations-bbox.csv" ...
#     Total "validation" images 64 ... of which will be loaded 64 ...
# ...

# %%
oidv6 downloader en --dataset path_to_directory --type_data train --classes Cat dOg --limit 10 --yesoidv6 downloader en --dataset path_to_directory --type_data train --classes Cat dOg --limit 10 --yesoidv6 downloader en --dataset path_to_directory --type_data train --classes Cat dOg --limit 10 --yes
